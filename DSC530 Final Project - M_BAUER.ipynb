# %% [markdown]
# # DSC 530 Term Project - Maddie Bauer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import thinkstats2
import thinkplot

# %%
import statistics

# %%
df = pd.read_csv(r'/Users/madelinebauer/datasets-696-1312-NBA.csv', encoding= 'unicode_escape')

# %%
# Check the df structure

df.head()
# Out:
#    Year           Team  Wins  Loss  Home Wins  Home Loss  Away Wins  \
# 0  1968  Atlanta Hawks    48    34         28         12         18
# 1  1969  Atlanta Hawks    48    34         25         13         18
# 2  1970  Atlanta Hawks    36    46         21         20         14
# 3  1971  Atlanta Hawks    36    46         22         19         13
# 4  1972  Atlanta Hawks    46    36         28         13         17
#
#    Away Loss   HomePCT   AwayPCT  TotalPCT
# 0         21  0.700000  0.461538  0.585366
# 1         16  0.657895  0.529412  0.585366
# 2         26  0.512195  0.350000  0.439024
# 3         26  0.536585  0.333333  0.439024
# 4         23  0.682927  0.425000  0.560976

# %%
# Check the size

df.shape

# 1216 rows, 11 variables
# Out:
# (1216, 11)

# %%
# Check the variable types

df.dtypes
# Out:
# Year           int64
# Team          object
# Wins           int64
# Loss           int64
# Home Wins      int64
# Home Loss      int64
# Away Wins      int64
# Away Loss      int64
# HomePCT      float64
# AwayPCT      float64
# TotalPCT     float64
# dtype: object

# %%
# Check for missing data

for c in df.columns:
    missing = df[c].isnull().sum()
    if missing > 0:
        print("{} has {} missing value(s)".format(c, missing))
    else:
        print("{} has NO missing values.".format(c))
# Out:
# Year has NO missing values.
# Team has NO missing values.
# Wins has NO missing values.
# Loss has NO missing values.
# Home Wins has NO missing values.
# Home Loss has NO missing values.
# Away Wins has NO missing values.
# Away Loss has NO missing values.
# HomePCT has NO missing values.
# AwayPCT has NO missing values.
# TotalPCT has NO missing values.

# %%
# Create a Histogram for all variables

for c in df.columns:
    plt.hist(df[c])
    plt.title("Histogram of " + c, fontsize = 12)
    plt.show()

# %%
# All relevant histograms look relatively normal. 
# non-relevant histograms = year and team

# %%
# Create df without the Team variable because all others are numeric

df2 = df[['Year', 'Wins', 'Loss', 'Home Wins', 'Home Loss', 'Away Wins', 'Away Loss', 'HomePCT', 'AwayPCT', 'TotalPCT']]

# %%
# Find the mean for each variable (excluding the Team variable)

for c in df2.columns:
    print(df2[c].mean())
# Out:
# 1987.125
# 40.182565789473685
# 40.18338815789474
# 24.39720394736842
# 14.66858552631579
# 14.674342105263158
# 24.40625
# 0.6247715317845405
# 0.37328365343667796
# 0.49990120038651314

# %%
# Find ALL descriptive stats.
df2.describe().round(2)
# Out:
#           Year     Wins     Loss  Home Wins  Home Loss  Away Wins  Away Loss  \
# count  1216.00  1216.00  1216.00    1216.00    1216.00    1216.00    1216.00
# mean   1987.12    40.18    40.18      24.40      14.67      14.67      24.41
# std      15.68    12.45    12.43       7.13       6.84       6.56       6.60
# min    1950.00     8.00    10.00       2.00       1.00       0.00       7.00
# 25%    1976.00    31.00    31.00      19.00      10.00      10.00      20.00
# 50%    1989.00    41.00    40.00      25.00      14.00      14.00      24.00
# 75%    2000.00    49.00    49.00      30.00      19.00      19.00      29.00
# max    2010.00    72.00    73.00      40.00      35.00      33.00      40.00
#
#        HomePCT  AwayPCT  TotalPCT
# count  1216.00  1216.00   1216.00
# mean      0.62     0.37      0.50
# std       0.17     0.16      0.15
# min       0.07     0.00      0.11
# 25%       0.51     0.24      0.39
# 50%       0.63     0.37      0.51
# ...

# %%
# Breakdown by each variable so I can report on PowerPoint easier

# %%
df2['Year'].describe().round(2)
# Out:
# count    1216.00
# mean     1987.12
# std        15.68
# min      1950.00
# 25%      1976.00
# 50%      1989.00
# 75%      2000.00
# max      2010.00
# Name: Year, dtype: float64

# %%
df2['Wins'].describe().round(2)
# Out:
# count    1216.00
# mean       40.18
# std        12.45
# min         8.00
# 25%        31.00
# 50%        41.00
# 75%        49.00
# max        72.00
# Name: Wins, dtype: float64

# %%
df2['Loss'].describe().round(2)
# Out:
# count    1216.00
# mean       40.18
# std        12.43
# min        10.00
# 25%        31.00
# 50%        40.00
# 75%        49.00
# max        73.00
# Name: Loss, dtype: float64

# %%
df2['Home Wins'].describe().round(2)
# Out:
# count    1216.00
# mean       24.40
# std         7.13
# min         2.00
# 25%        19.00
# 50%        25.00
# 75%        30.00
# max        40.00
# Name: Home Wins, dtype: float64

# %%
df2['Home Loss'].describe().round(2)
# Out:
# count    1216.00
# mean       14.67
# std         6.84
# min         1.00
# 25%        10.00
# 50%        14.00
# 75%        19.00
# max        35.00
# Name: Home Loss, dtype: float64

# %%
df2['Away Wins'].describe().round(2)
# Out:
# count    1216.00
# mean       14.67
# std         6.56
# min         0.00
# 25%        10.00
# 50%        14.00
# 75%        19.00
# max        33.00
# Name: Away Wins, dtype: float64

# %%
df2['Away Loss'].describe().round(2)
# Out:
# count    1216.00
# mean       24.41
# std         6.60
# min         7.00
# 25%        20.00
# 50%        24.00
# 75%        29.00
# max        40.00
# Name: Away Loss, dtype: float64

# %%
df2['HomePCT'].describe().round(2)
# Out:
# count    1216.00
# mean        0.62
# std         0.17
# min         0.07
# 25%         0.51
# 50%         0.63
# 75%         0.76
# max         0.98
# Name: HomePCT, dtype: float64

# %%
df2['AwayPCT'].describe().round(2)
# Out:
# count    1216.00
# mean        0.37
# std         0.16
# min         0.00
# 25%         0.24
# 50%         0.37
# 75%         0.49
# max         0.82
# Name: AwayPCT, dtype: float64

# %%
df2['TotalPCT'].describe().round(2)
# Out:
# count    1216.00
# mean        0.50
# std         0.15
# min         0.11
# 25%         0.39
# 50%         0.51
# 75%         0.61
# max         0.88
# Name: TotalPCT, dtype: float64

# %%
df2.dtypes
# Out:
# Year           int64
# Wins           int64
# Loss           int64
# Home Wins      int64
# Home Loss      int64
# Away Wins      int64
# Away Loss      int64
# HomePCT      float64
# AwayPCT      float64
# TotalPCT     float64
# dtype: object

# %% [markdown]
# ### PMF

# %%
# PMF
# Above average HomePCT (mean = 0.62)
# Below average HomePCT (mean = 0.62)

# %%
group3 = df[df.Year < 1987]
group4 = df[df.Year >= 1987]

group3Hist = thinkstats2.Hist(group3.HomePCT, label='1950-1987')
group4Hist = thinkstats2.Hist(group4.HomePCT, label='1987-2010')

width = 0.4
thinkplot.PrePlot(2)
thinkplot.Hist(group3Hist, align='right', width=width)
thinkplot.Hist(group4Hist, align='left', width=width)
thinkplot.Show(xlabel='Home Win Percentage', ylabel='Frequency')

# %%
group3PMF = thinkstats2.Pmf(group3Hist)
group4PMF = thinkstats2.Pmf(group4Hist)

thinkplot.PrePlot(2, cols=2)
thinkplot.Hist(group3PMF, align='right', width=width)
thinkplot.Hist(group4PMF, align='left', width=width)
thinkplot.Config(xlabel='Home Win Percentage', ylabel='Probability')

thinkplot.PrePlot(2)
thinkplot.SubPlot(2)
thinkplot.Pmfs([group3PMF, group4PMF])
thinkplot.Show(xlabel='Home Win Percentage', ylabel = "Probability")

# %% [markdown]
# ### CDF

# %%
# CDF
Total_PCT = df2['TotalPCT']
Home_PCT = df2['HomePCT']
Away_PCT = df2['AwayPCT']

# %%
first_cdf = thinkstats2.Cdf(Total_PCT, label='Total Win Percentage')
thinkplot.PrePlot(2)
thinkplot.Cdfs([first_cdf])
thinkplot.Show(xlabel='Total Win Percentage', ylabel='CDF')

# %%
second_cdf = thinkstats2.Cdf(Home_PCT, label='Home Win Percentage')
thinkplot.PrePlot(2)
thinkplot.Cdfs([second_cdf])
thinkplot.Show(xlabel='Home Win Percentage', ylabel='CDF')

# %%
thinkplot.PrePlot(2)
thinkplot.Cdfs([first_cdf, second_cdf])
thinkplot.Show(xlabel='Percentage of Wins', ylabel='CDF')

# %%
third_cdf = thinkstats2.Cdf(Away_PCT, label='Away Win Percentage')
thinkplot.PrePlot(2)
thinkplot.Cdfs([third_cdf])
thinkplot.Show(xlabel='Away Win Percentage', ylabel='CDF')

# %%
thinkplot.PrePlot(2)
thinkplot.Cdfs([third_cdf, second_cdf])
thinkplot.Show(xlabel='Percentage of Wins', ylabel='CDF')

# %% [markdown]
# ### Normal Probablilty Plots

# %%
# Normal Probablilty Plots
# Followed code from ThinkStats2

# %%
# 1
mean, var = thinkstats2.TrimmedMeanVar(df2.TotalPCT, p=0.01)
std = np.sqrt(var)

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, mean, std)
thinkplot.Plot(fxs, fys, linewidth=4, color='0.8')

xs, ys = thinkstats2.NormalProbability(df2.TotalPCT)
thinkplot.Plot(xs, ys, label='Total Win Percentage')

thinkplot.Config(title='Normal Probability Plot',
                 xlabel='Standard deviations from mean',
                 ylabel='Total Win Percentage')

# %%
# 2
mean, var = thinkstats2.TrimmedMeanVar(df2.HomePCT, p=0.01)
std = np.sqrt(var)

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, mean, std)
thinkplot.Plot(fxs, fys, linewidth=4, color='0.8')

xs, ys = thinkstats2.NormalProbability(df2.HomePCT)
thinkplot.Plot(xs, ys, label='Home Win Percentage')

thinkplot.Config(title='Normal Probability Plot',
                 xlabel='Standard deviations from mean',
                 ylabel='Home Win Percentage')

# %%
# 3
mean, var = thinkstats2.TrimmedMeanVar(df2.AwayPCT, p=0.01)
std = np.sqrt(var)

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, mean, std)
thinkplot.Plot(fxs, fys, linewidth=4, color='0.8')

xs, ys = thinkstats2.NormalProbability(df2.AwayPCT)
thinkplot.Plot(xs, ys, label='Away Win Percentage')

thinkplot.Config(title='Normal Probability Plot',
                 xlabel='Standard deviations from mean',
                 ylabel='Away Win Percentage')

# %% [markdown]
# # Correlation and Scatter Plots

# %%
def Cov(xs, ys, meanx=None, meany=None):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    if meanx is None:
        meanx = np.mean(xs)
    if meany is None:
        meany = np.mean(ys)

    cov = np.dot(xs-meanx, ys-meany) / len(xs)
    return cov

def Corr(xs, ys):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    meanx, varx = thinkstats2.MeanVar(xs)
    meany, vary = thinkstats2.MeanVar(ys)

    corr = Cov(xs, ys, meanx, meany) / np.sqrt(varx * vary)
    return corr

# %%
Corr(df2['HomePCT'], df2['AwayPCT'])
# Out:
# 0.7057476500520222

# %% [markdown]
# ### Scatter Plot #1

# %%
thinkplot.Scatter(df2['HomePCT'], df2['AwayPCT'])
thinkplot.Show(xlabel='Home Win Percentage', ylabel='Away Win Percentage')

# %%
plt.plot(df2.HomePCT + np.random.normal(0,0.01,len(df2)),df2.AwayPCT + np.random.normal(0,0.01,len(df2)),'o', alpha = 0.5)
plt.plot([0,1],[0,1])
plt.xlabel('Home PCT')
plt.ylabel('Away PCT')
plt.title('Home vs Away Percentage in the NBA')
# Out:
# Text(0.5, 1.0, 'Home vs Away Percentage in the NBA')

# %%
# All data points below the orange line support home court advantage.
# It is clear that home court advantage is a thing!
# The orange line is y=x so the "fair" line that would be 50/50 chance.
# Correlation: 0.7057476500520222

# %% [markdown]
# ### Scatter Plot #2

# %%
Corr(df2['HomePCT'], df2['TotalPCT'])
# Out:
# 0.9272510073198853

# %%
thinkplot.Scatter(df2['HomePCT'], df2['TotalPCT'])
thinkplot.Show(xlabel='Home Win Percentage', ylabel='Total Win Percentage')

# %%
plt.plot(df2.HomePCT + np.random.normal(0,0.01,len(df2)),df2.TotalPCT + np.random.normal(0,0.01,len(df2)),'o', alpha = 0.5)
plt.plot([0,1],[0,1])
plt.xlabel('Home PCT')
plt.ylabel('Total PCT')
plt.title('Home vs Total Percentage in the NBA')
# Out:
# Text(0.5, 1.0, 'Home vs Total Percentage in the NBA')

# %%
# All data points below the orange line support home court advantage.
# Most teams perform better at home than overall.
# The orange line is y=x so the "fair" line that would be 50/50 chance.
# Correlation: 0.9272510073198853

# %% [markdown]
# # Hypothesis Testing

# %%
# code followed from p. 102 of text

class HypothesisTest(object):
    
    def __init__(self, data):
        self.data = data
        self.MakeModel()
        self.actual = self.TestStatistic(data)
    
    def PValue(self, iters=1000):
        self.test_stats = [self.TestStatistic(self.RunModel())
                           for _ in range(iters)]
        count = sum(1 for x in self.test_stats if x >= self.actual)
        return count / iters
    
    def TestStatistic(self, data):
        raise UnimplementedMethodException()
        
    def MakeModel(self):
        pass
    
    def RunModel(self):
        raise UnimplementedMethodExcepti

# %%
# code followed from p. 104 of text


class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.mean() - group2.mean())
        return test_stat

    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

# %%
data = df2.HomePCT, df2.AwayPCT
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
print(pvalue)
# Out:
# 0.0

# %%
data2 = df2.HomePCT, df2.TotalPCT
ht2 = DiffMeansPermute(data2)
pvalue2 = ht.PValue()
print(pvalue2)
# Out:
# 0.0

# %% [markdown]
# # Regression

# %%
# I'm not convinced regression is necessary in my case. 
# I do not have enough variables to work with.

# %%
import statsmodels.formula.api as smf

# %%
formula1 = 'HomePCT ~ AwayPCT'

formula2 = 'TotalPCT ~ HomePCT'

# %%
# model1
model = smf.ols(formula1, data = df2)
results = model.fit()

# %%
print(results.params)
results.summary()
# 49.8% of variation in the HomePCT is related to TotalPCT
# Out:
# Intercept    0.344195
# AwayPCT      0.751645
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                HomePCT   R-squared:                       0.498
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     1205.
# Date:                Wed, 05 Aug 2020   Prob (F-statistic):          6.25e-184
# Time:                        12:07:05   Log-Likelihood:                 858.26
# No. Observations:                1216   AIC:                            -1713.
# Df Residuals:                    1214   BIC:                            -1702.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Model2 used
model2 = smf.ols(formula2, data = df2)
results2 = model2.fit()
print(results2.params)
results2.summary()

# 86% of variation in the TotalPCT is related to HomePCT
# Out:
# Intercept   -0.015782
# HomePCT      0.825395
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               TotalPCT   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     7445.
# Date:                Wed, 05 Aug 2020   Prob (F-statistic):               0.00
# Time:                        12:08:30   Log-Likelihood:                 1775.2
# No. Observations:                1216   AIC:                            -3546.
# Df Residuals:                    1214   BIC:                            -3536.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# slope and intercept from model
slope = 0.8254
intercept = -0.0158
equation = slope*df2['HomePCT'] + intercept

# %%
# Graph linear model2
# scatter plot with line of best fit
x = np.linspace(-0.1, 1, 100)
y = slope*x + intercept
plt.plot(x, y, '-r', label = 'y=0.8254x - 0.0158')
plt.scatter(df2['HomePCT'], df2['TotalPCT'], alpha = 0.3)
plt.title("Linear Regression Model")
plt.xlabel('Home Win Percentage')
plt.ylabel('Total Win Percentage')
plt.show()
